# %% [markdown]
# <a href="https://colab.research.google.com/github/greatsong/2020_public_data_analysis/blob/master/%EC%BD%94%EB%9E%A9%EC%82%AC%EC%9A%A9%EB%B2%95(200824_%EC%86%A1%EC%84%9D%EB%A6%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 예제 코드(1) - 간단한 그래프 그리기
# 코드를 작성한 후 왼쪽 실행 버튼을 눌러주세요!

import matplotlib.pyplot as plt
plt.plot([1,2,3,5,4])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
# 예제 코드(2) - 파일 업로드하기

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdf10095-eaa2-4c30-a845-e91e8510df3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdf10095-eaa2-4c30-a845-e91e8510df3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving age2007.csv to age2007.csv

# %%
# 업로드가 잘되었나 확인하고 싶으면 다음 명령어를 실행하세요!
# !ls
# Out:
# age2007.csv  sample_data

# %%
# 예제 코드(3) - 깃헙 레파지토리(저장소) 불러오기

# !git clone https://github.com/greatsong/2020_public_data_analysis
# Out:
# Cloning into '2020_public_data_analysis'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 20 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (20/20), done.

# %%
# !ls
# Out:
# 2020_public_data_analysis  age2007.csv	sample_data

# %%
cd 2020_public_data_analysis/
# Out:
# /content/2020_public_data_analysis

# %%
ls
# Out:
#  2019_2020_3_4월_초미세먼지데이터비교.ipynb
#  dustDetailInfo_2019_03.csv
#  dustDetailInfo_2019_03.xls
#  dustDetailInfo_2019_04.csv
#  dustDetailInfo_2019_04.xls
#  dustDetailInfo_2020_03.csv
#  dustDetailInfo_2020_03.xls
#  dustDetailInfo_2020_04.csv
#  dustDetailInfo_2020_04.xls
# '우리나라는 점점 여름과 겨울이 길어지고 있을까.ipynb'
#  ta_20200721103344.csv

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
for row in data :
  print(row)
  break
# Out:
# ['1907-10-01', '108', '13.5', '7.9', '20.7']

# %%
# 예제 코드(4) - 한글 폰트 사용하기
 
# !apt -qq -y install fonts-nanum
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 폰트 세팅
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()

# %%
# 위 코드 실행 후 [메뉴] - [런타임] - [런타임 다시 시작] - [예]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic') 
plt.title('한글 제목')
plt.plot([1,2,3,5,4])
plt.show()

# %%
print('수고하셨습니다'+'!'*10)
# Out:
# 수고하셨습니다!!!!!!!!!!
