# %% [markdown]
# https://data.kma.go.kr/climate/heatWave/selectHeatWaveDmap.do?pgmNo=106
# 폭염일수 그래프로 확인해보기

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))

for row in data : 
    print(row)
    break
# Out:
# ['1907-10-01', '108', '13.5', '7.9', '20.7']

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
summer20 = 0
summer21 = 0
winter20 = 0
winter21 = 0

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    if 1980 <= year < 2000 and float(row[-1]) > 30 :
        summer20 += 1
    elif 2000 <= year < 2020 and float(row[-1]) > 30 :
        summer21 += 1
print(summer20, summer21)
# Out:
# 611 793

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))

gap = [1960,1980,2000]
result = {1960:0, 1980:0, 2000:0}

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    for i in gap : 
        if i <= year < i + 20 and float(row[-1]) > 30 :
            result[i] += 1
            
print(result)
# Out:
# {1960: 620, 1980: 611, 2000: 793}

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))

gap = [1960,1970,1980,1990,2000]
result = {1960:0, 1970:0, 1980:0, 1990:0, 2000:0}

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    for i in gap : 
        if i <= year < i + 10 and float(row[-1]) > 30 :
            result[i] += 1
            
print(result)
# Out:
# {1960: 332, 1970: 288, 1980: 259, 1990: 352, 2000: 324}

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
result = {}
for i in range(1980,2020) : 
    result[i] = 0 

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    if 1980 <= year < 2020 and float(row[-1]) > 30 :
        result[year] += 1
print(result)
# Out:
# {1980: 6, 1981: 29, 1982: 30, 1983: 24, 1984: 39, 1985: 36, 1986: 15, 1987: 15, 1988: 34, 1989: 31, 1990: 33, 1991: 30, 1992: 27, 1993: 13, 1994: 54, 1995: 24, 1996: 33, 1997: 58, 1998: 33, 1999: 47, 2000: 52, 2001: 56, 2002: 19, 2003: 16, 2004: 35, 2005: 30, 2006: 27, 2007: 35, 2008: 30, 2009: 24, 2010: 44, 2011: 36, 2012: 41, 2013: 48, 2014: 40, 2015: 57, 2016: 56, 2017: 50, 2018: 54, 2019: 43}

# %%
import matplotlib.pyplot as plt
plt.plot(list(result.values()))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(result.keys(), result.values())
plt.show()

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
result = {}
for i in range(1960,2020) : 
    result[i] = 0 

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    if 1960 <= year < 2020 and float(row[-1]) > 30 :
        result[year] += 1
import matplotlib.pyplot as plt
plt.bar(result.keys(), result.values())
plt.show()

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
result = {}
for i in range(1960,2020) : 
    result[i] = 0 

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    if 1960 <= year < 2020 and float(row[-1]) > 33 :
        result[year] += 1
        
import matplotlib.pyplot as plt
plt.bar(result.keys(), result.values())
plt.show()

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
result = {}
for i in range(1960,2020) : 
    result[i] = 0 

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-1] == '' :
        row[-1] = 0
    if 1960 <= year < 2020 and 15 < float(row[-1]) < 25 :
        result[year] += 1
        
import matplotlib.pyplot as plt
plt.bar(result.keys(), result.values())
plt.show()

# %%
import csv
data = csv.reader(open('ta_20200721103344.csv', encoding = 'cp949'))
result = {}
for i in range(1960,2020) : 
    result[i] = 0 

for row in data : 
    date = row[0].split('-')
    year = int(date[0])
    if row[-2] == '' :
        row[-2] = 0
    if 1960 <= year < 2020 and  float(row[-2]) < -5 :
        result[year] += 1
        
import matplotlib.pyplot as plt
plt.bar(result.keys(), result.values())
plt.show()

# %%
import pandas as pd
df = pd.read_csv('ta_20200721103344_header.csv', encoding = 'cp949')
df
# Out:
#                날짜  지역코드    평균    최저    최고
# 0      1907-10-01   108  13.5   7.9  20.7
# 1      1907-10-02   108  16.2   7.9  22.0
# 2      1907-10-03   108  16.2  13.1  21.3
# 3      1907-10-04   108  16.5  11.2  22.0
# 4      1907-10-05   108  17.6  10.9  25.4
# ...           ...   ...   ...   ...   ...
# 40766  2020-07-16   108  25.0  20.4  29.7
# 40767  2020-07-17   108  26.0  21.5  31.6
# 40768  2020-07-18   108  26.1  22.8  31.0
# 40769  2020-07-19   108  24.0  20.6  26.6
# 40770  2020-07-20   108  23.8  22.4  26.6
#
# [40771 rows x 5 columns]

# %%
df.describe()
# Out:
#           지역코드            평균            최저            최고
# count  40771.0  40015.000000  40014.000000  40013.000000
# mean     108.0     11.729294      7.432399     16.741204
# std        0.0     10.656384     10.878462     10.985124
# min      108.0    -19.200000    -23.100000    -16.300000
# 25%      108.0      2.700000     -1.400000      7.200000
# 50%      108.0     12.900000      8.000000     18.600000
# 75%      108.0     21.200000     17.100000     26.300000
# max      108.0     33.700000     30.300000     39.600000

# %%
df = df.fillna(0)

# %%
df.describe()
# Out:
#           지역코드            평균            최저            최고
# count  40771.0  40771.000000  40771.000000  40771.000000
# mean     108.0     11.511803      7.294400     16.429958
# std        0.0     10.675045     10.823598     11.115003
# min      108.0    -19.200000    -23.100000    -16.300000
# 25%      108.0      2.200000     -1.200000      6.600000
# 50%      108.0     12.500000      7.600000     18.200000
# 75%      108.0     21.100000     16.900000     26.200000
# max      108.0     33.700000     30.300000     39.600000

# %%
df['최고']
# Out:
# 0        20.7
# 1        22.0
# 2        21.3
# 3        22.0
# 4        25.4
#          ...
# 40766    29.7
# 40767    31.6
# 40768    31.0
# 40769    26.6
# 40770    26.6
# Name: 최고, Length: 40771, dtype: float64

# %%
df['최고'] > 30
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40766    False
# 40767     True
# 40768     True
# 40769    False
# 40770    False
# Name: 최고, Length: 40771, dtype: bool

# %%
df[df['최고'] > 30]
# Out:
#                날짜  지역코드    평균    최저    최고
# 266    1908-06-23   108  24.4  18.3  32.4
# 267    1908-06-24   108  23.7  19.5  31.0
# 280    1908-07-07   108  23.5  17.3  30.3
# 285    1908-07-12   108  24.8  19.8  30.4
# 287    1908-07-14   108  25.3  20.0  31.2
# ...           ...   ...   ...   ...   ...
# 40758  2020-07-08   108  25.5  21.3  30.4
# 40759  2020-07-09   108  27.5  21.8  32.9
# 40761  2020-07-11   108  25.8  22.2  30.2
# 40767  2020-07-17   108  26.0  21.5  31.6
# 40768  2020-07-18   108  26.1  22.8  31.0
#
# [3876 rows x 5 columns]

# %%
df[df['최고'] > 30]['날짜']
# Out:
# 266      1908-06-23
# 267      1908-06-24
# 280      1908-07-07
# 285      1908-07-12
# 287      1908-07-14
#             ...
# 40758    2020-07-08
# 40759    2020-07-09
# 40761    2020-07-11
# 40767    2020-07-17
# 40768    2020-07-18
# Name: 날짜, Length: 3876, dtype: object

# %%
pd.DatetimeIndex(df['날짜']).year
# Out:
# Int64Index([1907, 1907, 1907, 1907, 1907, 1907, 1907, 1907, 1907, 1907,
#             ...
#             2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020],
#            dtype='int64', name='날짜', length=40771)

# %%
df['year'] = pd.DatetimeIndex(df['날짜']).year

# %%
df.head()
# Out:
#            날짜  지역코드    평균    최저    최고  year
# 0  1907-10-01   108  13.5   7.9  20.7  1907
# 1  1907-10-02   108  16.2   7.9  22.0  1907
# 2  1907-10-03   108  16.2  13.1  21.3  1907
# 3  1907-10-04   108  16.5  11.2  22.0  1907
# 4  1907-10-05   108  17.6  10.9  25.4  1907

# %%
df[df['최고'] > 30]['year'].value_counts()
# Out:
# 1943    71
# 1939    69
# 1942    66
# 1949    58
# 1997    58
#         ..
# 1936    14
# 1993    13
# 1913    12
# 1934    11
# 1980     6
# Name: year, Length: 110, dtype: int64

# %%
df[df['최고'] > 30]['year'].value_counts().sort_index()
# Out:
# 1908    23
# 1909    31
# 1910    24
# 1911    31
# 1912    22
#         ..
# 2016    56
# 2017    50
# 2018    54
# 2019    43
# 2020    19
# Name: year, Length: 110, dtype: int64

# %%
df[df['최고'] > 30]['year'].value_counts().sort_index().plot.bar()

# %%
df[(df['최고'] > 30) & (df['year'] > 1980)]['year'].value_counts().sort_index().plot.bar()
